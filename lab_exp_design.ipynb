# %% [markdown]
# # Welcome to Lab: Experimental Design 👨‍🔬⚗️🧪
#
# Before this lab section, you completed the "Hello Survey" based on the questions you generated with your groups.  This week, you will do an analysis of the results and explore techniques to do great experimental design in Python!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Xiaocong"
ca1_name = "Shannon"
ca2_name = "Aishwarya"


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "Eric Zhang"
partner1_netid = "ericrz2"
partner1_inYourGroupLastWeek = "yes"

partner2_name = "John Vasiliades"
partner2_netid = "jvasi2"
partner1_inYourGroupLastWeek = "yes"

partner3_name = ""
partner3_netid = ""
partner1_inYourGroupLastWeek = "yes"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello Dataset Analysis
#
# In lab last week, you created a series of questions that made up the **"Hello Dataset"**.  Before lab, you completed this survey along with the entire course.  Today, you're going to do analysis on this dataset! :)

# %% [markdown]
# ## Your Binary Question Analysis
#
# You will be analyzing the **binary question** your group asked the class from `lab_pandas` -- record it below.  If multiple people from your group had different binary questions, decide which one to use and record that question below.

# %% [markdown]
# *(Coke or Pepsi?)*

# %% [markdown]
# ## Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-fa23.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df`. Don't forget to import pandas as well!

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa23.csv")

# %% [markdown]
# ## Find The Variable for Your Question
#
# The command `df.columns.tolist()` will **list all of the columns (variables)** in a DataFrame.  Use `df.columns.tolist()` and read the output until you find the column name for your binary question.
#
# - You may see the message: `Output exceeds the __size limit__. Open the full output data __in a text editor__`
# - If you do, click the **`__in a text editor__`** link to open the whole list in a new tab. :)

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Section',
#  'Does your NetID ending with odd number or even number?',
#  'If I flipped a coin, do you think it would it land on heads or tails?',
#  'Do you like to eat tacos or donuts?',
#  'Pick a Number: 0 or 1',
#  'Are you a freshman in college?',
#  'Are you a morning or a night person?',
#  'Are you a morning or an afternoon person?',
#  'Are you a student from Illinois or out-of-state?',
#  'Are you a student in Grainger?',
#  'Are you a Taylor Swift fan?',
#  'Are you a winter or summer person?',
#  'Are you above or equal to 5 foot 6 inches?',
#  'Are you an early bird or night owl?',
#  'Are you an extrovert or an introvert?',
#  'Are you an international student or from the United States?',
#  'Are you an underclassmen or lowerclassmen?',
#  'Is the day of the month of your birth even or odd?  (Ex: May 28 is even, but June 3 is odd)',
#  'Are you from the Chicago suburbs?',
#  'Are you in LAS?',
#  'Are you in the 9:00 AM or 11:00 AM DISCOVERY lecture?',
#  'Are you involved/will be involved in Greek life?',
#  'Are you living on or off campus?',
#  'Do you identify as a male or female?',
#  'Are you older than 18?',
#  'Are you sitting in a light or dark colored chair?',
#  'Are you the first person from your entire family to attend University of Illinois?',
#  'Are you wearing glasses right now?',
#  'Are your parents immigrants?',
#  'Beef or Chicken?',
#  'Chocolate or Vanilla?',
#  'Coffee or Tea?',
#  'Coke or Pepsi? ',
#  'Did you attend lecture on Friday?',
#  'Did you grow up in the Midwest?',
#  'Did you move in from the 13-16th or the 17-20th?',
#  'Did you sit on the left or the right side of the hall during the last lecture?',
#  'Do you consider a cup to be half empty or half full?',
#  'Do you dance?',
#  'Do you drink black coffee?',
#  'Do you drink coffee every day?',
#  'Do you eat breakfast in the morning?',
#  'Do you grow up in Illinois?',
#  'Do you hang your toilet paper over or under?',
#  'Do you have an iPhone?',
#  'Do you have an odd or even amount of letters in your first name?',
#  'Do you have any siblings?',
#  'Do you have black hair or non-black hair?',
#  'Do you have brown eyes or any other color?',
#  'Do you have short hair or long hair?',
#  'Do you have your Data Science Discovery lab section on Wednesday or after Wednesday?',
#  'Do you have your ears pierced?',
#  'Do you introduce yourself to a new person using "hi" or "hello"?',
#  'Do you like C++ or Java?',
#  'Do you like Chinese food?',
#  'Do you like dogs or cats?',
#  'Do you like football or basketball better?',
#  'Do you like ice cream?',
#  'Do you like orange juice or apple juice?',
#  'Do you like pancakes or waffles?',
#  'Pink or Blue?',
#  'Pizza or a burger?',
#  'Pizza or pasta?',
#  'Summer or Winter?',
#  'Do you like to wear hats?',
#  'Do you like UIUC?',
#  'Do you listen to music on the way to classes?',
#  'Do you live in a residence hall or private housing?',
#  'Do you prefer Nike or Adidas for shoes?',
#  'Do you prefer vanilla or chocolate ice cream? ',
#  'Burger or Taco?',
#  'Do you prefer American Football or Cricket?',
#  'Do you prefer apples or bananas?',
#  'Do you prefer blue or orange? ',
#  'Do you prefer blue or pink?',
#  'Do you prefer chipmunks or squirrels?',
#  'Do you prefer Coke or Sprite? ',
#  'Do you prefer cold drinks or hot drinks?',
#  'Do you prefer cold or hot weather?',
#  'Do you prefer crinkle-cut or straight-cut fries?',
#  'Do you prefer earbuds or headphones?',
#  'Do you prefer fall or spring?',
#  'Do you prefer fall or summer?',
#  'Do you prefer green or red?',
#  'Do you prefer Hot Cheetos or Takis?',
#  'Do you prefer Hot Coffee or Ice Coffee?',
#  'Do you prefer hot or iced tea?',
#  'Do you prefer hotdogs or burgers?',
#  'Do you prefer ketchup or ranch?',
#  'Do you prefer Mac or Windows?',
#  'Do you prefer Marvel or DC comics?',
#  'Do you prefer movies or TV shows?',
#  'Do you prefer online class or in-person class?',
#  'Pizza or tacos?',
#  'Do you prefer red or blue?',
#  'Do you prefer regular or diet soda?',
#  'Do you prefer Soccer or American Football?',
#  'Do you prefer spend your time outdoor or indoor?',
#  'Superman or batman?',
#  'Do you prefer sweet or salty foods?',
#  'Do you prefer sweet or savory food?',
#  'Do you prefer sweet or sour foods?',
#  'Do you prefer the color YELLOW or the color ORANGE?',
#  'Do you prefer the letter "M" or "N"?',
#  'Do you prefer the number 3 or the number 4?',
#  'Do you prefer to eat at ISR or IKE?',
#  'Do you prefer to have pets or no pets?',
#  'Do you prefer to listen to audio through headphones or speakers?',
#  'Do you prefer to shower at night or in the morning?',
#  'Do you prefer vegetables or fruit?',
#  'Do you pronounce caramel as "care-a-mel" or "car-mel"?',
#  'Do you pronounce Illinois "Ill-uh-noise" or "Ill-uh-noy"?',
#  'Do you pronounce the word "data" like "dah-tah" or "day-tah?"',
#  'Do you put ketchup on your hotdog?',
#  'Do you speak a language other than English?',
#  'Do you think there are more doors or wheels in the world?',
#  'Do you use Spotify or Apple Music?',
#  'Do you walk to class?',
#  'Do you wear glasses or contacts?',
#  'Does pineapple belong on pizza?',
#  'Does your first name start with a letter between A-M? (including A and M)?',
#  'Does your last name start with any letter between "A" through "L" or "M" through "Z"?',
#  'Does your UIN end with an even number or an odd number? (0 is considered an even number)',
#  'Folklore or Evermore?',
#  'Have you traveled outside of the USA this summer?',
#  'Have you ever traveled outside the USA?',
#  'Is a hotdog a sandwich?',
#  'Is math red or blue?',
#  'Is the last digit of your phone number even?',
#  'Is water wet?',
#  'Is your age an even number or an odd number?',
#  'Is your month of your birth odd or even?',
#  'Is your birthday before/on or after July 1st?',
#  'Is your day good or bad?',
#  'Is your dorm/apartment room number even?',
#  'Is your favorite color blue?',
#  'Is your favorite number even?',
#  'Is your major STEM or a humanity?',
#  'Lebron or Jordan?',
#  'Popeyes or KFC?',
#  'Was UIUC your first choice school when applying for college? ',
#  'Were you born before Feb. 14, 2005?',
#  'What came first, the chicken or the egg?',
#  'Which is the better ice cream flavor: chocolate chip or vanilla?',
#  'Which movie do you prefer Barbie or Oppenheimer?',
#  'Which number do you prefer: 49 or 62?',
#  'Which Ryan is better, Ryan Gosling or Ryan Reynolds?',
#  'which sequence do you prefer more tbge5 or pbt2l?',
#  'Who would win in a fight, Cinderella or Snow White?',
#  'Would you choose Mexican or Italian food?',
#  'Would you prefer to live an urban or rural life?',
#  'Would you rather get a book about your past or a letter revealing something about your future?',
#  'Would you rather go to an amusement park or beach?',
#  'Would you rather have a personal theme song that plays every time you enter a room, or have a spotlight follow you everywhere you go?',
#  'Would you rather have hiccups for the rest of your life or constantly feel like you have to sneeze?',
#  'Would you rather know how you die or when you die?',
#  'Would you rather never use a phone or computer again?',
#  'Would you rather take notes on a computer/tablet or paper?',
#  'In terms of Data Science, do you prefer statistics or computer science?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a day?',
#  'How many siblings do you have?',
#  'What is your phone battery percentage currently at?',
#  'How many people is the ideal number of people at a party?',
#  'What is the lowest numbered course you are taking this semester?',
#  'What is your shoe size (US size)?',
#  'From 1 to 10, how happy are you right now?',
#  "The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?",
#  'What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)',
#  'What do you think is the hardest major at UIUC?',
#  'What genre of music do you listen to?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'How do you respond to I-L-L?',
#  'What is your favorite game to play (either video game or IRL)?',
#  'What is your dream vacation location?']

# %% [markdown]
# ## Record the Variable for Your Question
#
# In the cell below, record your question's column name as a **string** variable named `analysis_column`.  You'll need that exact column name to reference data from that cell.

# %%
analysis_column =  "Coke or Pepsi? "
analysis_column
# Out:
# 'Coke or Pepsi? '

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df' in vars()), "You do not have a DataFrame called `df`."
assert(len(df) >= 965), "You have not loaded the correct Hello dataset"
assert(analysis_column in df), "Make certain your analysis_column string is EXACTLY as it appears in the Hello Dataset."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Column Subset: View Only Your Question's Responses
#
# To begin your question's analysis, you first want to **focus only on your question**.  In lecture, we have primarily focused on creating subsets of rows. However, you can also create a subset of columns!
#
# To create a DataFrame with just a single column, you can use the syntax:
# ```
# df[ ["column name"] ]
# ```
# - Notice the **double set of square brackets**.  You need the outer set for `df`, and the inner set for the column name.
# - Because we've already loaded your question into `analysis_column`, you won't need the quotation marks this time
# - You can find this syntax under the "Subset Variables (Columns)" on your Pandas cheat sheet!
#
# With the `analysis_column` variable from above, use Python to display only the column you're analyzing.  This will make it easy to see what the two options were for your question:

# %%
df[[analysis_column]]
# Out:
#     Coke or Pepsi?
# 0              Coke
# 1               NaN
# 2              Coke
# 3              Coke
# 4              Coke
# ..              ...
# 960            Coke
# 961           Pepsi
# 962            Coke
# 963            Coke
# 964            Coke
#
# [965 rows x 1 columns]

# %% [markdown]
# ## DataFrame: Group One
#
# Create a DataFrame, `df1`, that contains everyone who picked the first option of your two answers.  *(Make sure to make this a subset of the original `df`, and not just your one column.)*

# %%
df1 = df[df[analysis_column] == "Coke"]
df1
# Out:
#                        Name Section  \
# 0               Prof. Karle  L1, L2
# 2                    Andrew     Y05
# 3                  Annabel      Y05
# 4                    Ayden      Y14
# 5                      Sens     Y30
# ..                      ...     ...
# 959                    Zoe      Y19
# 960  Mohammed Fatheen Ahmed     Y22
# 962                   Nyssa     Y23
# 963                  maddax      Y2
# 964              CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 2                        NetID ends with an odd number
# 3                       NetID ends with an even number
# 4                       NetID ends with an even number
# 5                       NetID ends with an even number
# ..                                                 ...
# 959                     NetID ends with an even number
# 960                      NetID ends with an odd number
# 962                      NetID ends with an odd number
# 963                      NetID ends with an odd number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 2                                                Heads
# 3                                                Heads
# 4                                                Heads
# 5                                                Heads
# ..                                                 ...
# 959                                              Heads
# 960                                              Heads
# 962                                              Heads
# 963                                              Tails
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 2                                 Tacos                    1.0
# 3                                 Tacos                    0.0
# 4                                Donuts                    1.0
# 5                                 Tacos                    1.0
# ..                                  ...                    ...
# 959                               Tacos                    1.0
# 960                              Donuts                    0.0
# 962                               Tacos                    1.0
# 963                               Tacos                    0.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 2              Freshman in College                         Night Person
# 3                   Not a Freshman                         Night Person
# 4              Freshman in College                         Night Person
# 5              Freshman in College                         Night Person
# ..                             ...                                  ...
# 959            Freshman in College                         Night Person
# 960            Freshman in College                       Morning Person
# 962            Freshman in College                         Night Person
# 963            Freshman in College                         Night Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 2                            Afternoon Person
# 3                            Afternoon Person
# 4                              Morning Person
# 5                              Morning Person
# ..                                        ...
# 959                          Afternoon Person
# 960                            Morning Person
# 962                          Afternoon Person
# 963                          Afternoon Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 2                                       Out-of-state  ...
# 3                                           Illinois  ...
# 4                                           Illinois  ...
# 5                                           Illinois  ...
# ..                                               ...  ...
# 959                                         Illinois  ...
# 960                                         Illinois  ...
# 962                                         Illinois  ...
# 963                                         Illinois  ...
# 964                                     Out-of-state  ...
#
#     From 1 to 10, how happy are you right now?  \
# 0                                          9.0
# 2                                          7.0
# 3                                          5.0
# 4                                          8.0
# 5                                          8.0
# ..                                         ...
# 959                                        7.0
# 960                                        3.0
# 962                                        8.0
# 963                                        1.0
# 964                                        8.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 2                                             moderate
# 3                                             Moderate
# 4                                               Strong
# 5                                             Moderate
# ..                                                 ...
# 959                                          Moderate
# 960                                             strong
# 962                                               mild
# 963                                            extreme
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 2                                                  LAS
# 3                                     ISchool and LAS
# 4                                                 Gies
# 5                                     Grainger and LAS
# ..                                                 ...
# 959                              School of Information
# 960                                                las
# 962                                                las
# 963                          finance with data science
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 2                                                CS
# 3                                 Computer science
# 4                                   Any engineering
# 5                                               ECE
# ..                                              ...
# 959                          Molecular engineering
# 960                                              CS
# 962                                             ece
# 963                                         general
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 2                                     rap                               Dave
# 3                              Rap or r&b                            Eminem
# 4                               Indie pop                      The Lumineers
# 5                                Shoegaze                        Fiona Apple
# ..                                    ...                                ...
# 959   Everything (pop, R&B, rap, country)                      Taylor Swift
# 960                                   rap                              Drake
# 962                                   pop                       taylor swift
# 963                                   rap                       lil uzi vert
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 2                                instagram                        I-N-I
# 3                                Snapchat                           INI
# 4                                 Snapchat                          INI
# 5                                  Twitter                        I-N-I
# ..                                     ...                          ...
# 959                                Tiktok                        I-N-I!
# 960                                   Snap                         ini
# 962                                twitter                          INI
# 963                               snapchat                          ini
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 2                                               soccer
# 3                             Volleyball or fortnight
# 4                                           Basketball
# 5                                            Fall Guys
# ..                                                 ...
# 959                                   Street Fighters
# 960                                       apex legends
# 962                                         code names
# 963                                        quiet game
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 0                            The Maldives
# 2                                  Hawaii
# 3                                 Greece
# 4                              Australia
# 5                                      PR
# ..                                    ...
# 959                               Greece
# 960                                europe
# 962                                greece
# 963                    middle of nowhere
# 964                                 Korea
#
# [755 rows x 178 columns]

# %% [markdown]
# ## DataFrame: Group Two
#
# Create a new DataFrame, `df2`, that contains everyone who picked the other answer:

# %%
df2 = df[df[analysis_column] == "Pepsi"]
df2
# Out:
#         Name Section Does your NetID ending with odd number or even number?  \
# 11     Finch     Y03                     NetID ends with an even number
# 16    binchi     Y35                      NetID ends with an odd number
# 20     Eric      Y10                      NetID ends with an odd number
# 29      Josh     Y21                     NetID ends with an even number
# 31     Sarah     Y09                      NetID ends with an odd number
# ..       ...     ...                                                ...
# 909      Ben     Y29                      NetID ends with an odd number
# 919     Kate     Y13                     NetID ends with an even number
# 920  Yamuna      Y34                      NetID ends with an odd number
# 925  Juliana     Y12                      NetID ends with an odd number
# 961    Peter     Y09                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 11                                               Tails
# 16                                               Tails
# 20                                               Heads
# 29                                               Tails
# 31                                               Heads
# ..                                                 ...
# 909                                              Tails
# 919                                              Tails
# 920                                              Tails
# 925                                              Heads
# 961                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 11                               Donuts                    0.0
# 16                                Tacos                    0.0
# 20                                Tacos                    1.0
# 29                                Tacos                    1.0
# 31                               Donuts                    0.0
# ..                                  ...                    ...
# 909                               Tacos                    0.0
# 919                               Tacos                    1.0
# 920                               Tacos                    1.0
# 925                               Tacos                    1.0
# 961                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 11                  Not a Freshman                       Morning Person
# 16             Freshman in College                       Morning Person
# 20             Freshman in College                         Night Person
# 29             Freshman in College                         Night Person
# 31                  Not a Freshman                         Night Person
# ..                             ...                                  ...
# 909            Freshman in College                         Night Person
# 919                 Not a Freshman                       Morning Person
# 920            Freshman in College                         Night Person
# 925            Freshman in College                       Morning Person
# 961                 Not a Freshman                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 11                             Morning Person
# 16                             Morning Person
# 20                           Afternoon Person
# 29                           Afternoon Person
# 31                           Afternoon Person
# ..                                        ...
# 909                          Afternoon Person
# 919                            Morning Person
# 920                          Afternoon Person
# 925                            Morning Person
# 961                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 11                                          Illinois  ...
# 16                                      Out-of-state  ...
# 20                                          Illinois  ...
# 29                                          Illinois  ...
# 31                                          Illinois  ...
# ..                                               ...  ...
# 909                                         Illinois  ...
# 919                                         Illinois  ...
# 920                                         Illinois  ...
# 925                                         Illinois  ...
# 961                                     Out-of-state  ...
#
#     From 1 to 10, how happy are you right now?  \
# 11                                         1.0
# 16                                         9.2
# 20                                         6.0
# 29                                         8.0
# 31                                         9.0
# ..                                         ...
# 909                                        8.0
# 919                                        9.0
# 920                                       10.0
# 925                                        8.0
# 961                                        5.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 11                                                 NaN
# 16                                                mild
# 20                                           Moderate
# 29                                                Mild
# 31                                              Strong
# ..                                                 ...
# 909                                               Mild
# 919                                           Moderate
# 920                                             strong
# 925                                               none
# 961                                             strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 11                                    College of Media
# 16                                                math
# 20                                         Accounting
# 29                                                Geis
# 31                                                 LAS
# ..                                                 ...
# 909                                           Business
# 919                              Fine and Applied Arts
# 920                                               Gies
# 925                                      Gies Business
# 961                                                 CS
#
#     What do you think is the hardest major at UIUC?  \
# 11                                              NaN
# 16                                             math
# 20                                     Engineering
# 29                                     Music Theory
# 31                                          Physics
# ..                                              ...
# 909                                     Engineering
# 919                                Computer Science
# 920                               Computer Science
# 925                                       Chemistry
# 961                                              CS
#
#     What genre of music do you listen to?  Who is your favorite music artist?  \
# 11                                    Yes                        Saint Asonia
# 16                                    R&B                                 jay
# 20                                    R&B                                Joji
# 29                               Operetta                             Hot Dad
# 31                                    Pop                            Doja Cat
# ..                                    ...                                 ...
# 909                                   Rap                               Drake
# 919                           Many genres  King Gizzard and the Lizard Wizard
# 920                                   rap                              Giveon
# 925                             Reggaeton                             Shakira
# 961                                  Jazz                                  Ye
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 11                                  TikTok                        I-N-I
# 16                                     ins                          ini
# 20                                  TikTok                        INOIS
# 29                                 Youtube              Ill? Get Better
# 31                                 Tik Tok                        I-N-I
# ..                                     ...                          ...
# 909                               Snapchat                          INI
# 919                              Pinterest                        I-N-I
# 920                                tik tok                        I-N-I
# 925                              Instagram                        I-N-N
# 961                                     QQ                         illi
#
#     What is your favorite game to play (either video game or IRL)?  \
# 11                                               Palia
# 16                                                FIFA
# 20                                           Guess Who
# 29                                  Secrets of Grindea
# 31                                        Overcooked 2
# ..                                                 ...
# 909                                             Soccer
# 919                       Animal Crossing New Horizons
# 920                                           monopoly
# 925                                       Call of Duty
# 961                                     Clash of clans
#
#     What is your dream vacation location?
# 11                                    NaN
# 16                                     LA
# 20                                    NaN
# 29                             Seychelles
# 31                                Bahamas
# ..                                    ...
# 909                         Isla  Mujeres
# 919                                 Japan
# 920                             bora bora
# 925                             Bora Bora
# 961                               Iceland
#
# [185 rows x 178 columns]

# %% [markdown]
# ## Analysis
#
# Discuss the following questions with your group and then write down your response!

# %% [markdown]
# **Q1: What percentage of people chose each of your two binary options?**

# %% [markdown]
# 83.32% for Coke and 19.68% for Pepsi.

# %% [markdown]
# **Q2: Did this surprise you? Why or why not? Write at least one complete sentence.**

# %% [markdown]
# This result did not surprise me because Coke is the most popular soda in the world.

# %% [markdown]
# **Q3: Do you think your question was the closest to a perfect 50/50 split among the whole class?**

# %% [markdown]
# Not by a long shot. Our question was way off the 50/50 goal.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Creating Treatment and Control Groups
#
# For the rest of this lab, we will consider the "Hello Dataset" to be a pre-survey of randomly selected participants for an upcoming experiment.  In lecture, you learned that a good experiment will split the participants into two groups: the "treatment" group and the "control" group.
#
# Recall that it is necessary to have both groups:
#
# - The "control" group is a comparison group that will receive a placebo and will act as a control to ensure that the treatment has an effect.
# - The "treatment" group will receive a treatment and we will look for differences between the results of this treatment group and the control group.

# %% [markdown]
# ## Part 2.1: Select a Treatment Group
#
# Select half (50%) of the participants from our original `df` to be in the treatment group and place them into a DataFrame called `treatment`.
# - Remember, you can ask your CAs, TAs, or use your **pandas cheat sheet** to help you out!

# %%
treatment = df.sample(frac=0.5)
treatment
# Out:
#                Name Section  \
# 499          Lucino     Y28
# 275          Ashton     Y03
# 634           Chris     Y30
# 553             Ray     Y29
# 75             Evie     Y09
# ..              ...     ...
# 620          Kieran     Y28
# 21           Jayden     Y36
# 651  Kooper Merrick     Y42
# 56          Tiffany     Y13
# 813            Erol     Y07
#
#     Does your NetID ending with odd number or even number?  \
# 499                     NetID ends with an even number
# 275                      NetID ends with an odd number
# 634                      NetID ends with an odd number
# 553                      NetID ends with an odd number
# 75                       NetID ends with an odd number
# ..                                                 ...
# 620                      NetID ends with an odd number
# 21                       NetID ends with an odd number
# 651                     NetID ends with an even number
# 56                       NetID ends with an odd number
# 813                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 499                                              Heads
# 275                                              Tails
# 634                                              Heads
# 553                                              Heads
# 75                                               Tails
# ..                                                 ...
# 620                                              Heads
# 21                                               Heads
# 651                                              Heads
# 56                                               Heads
# 813                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 499                               Tacos                    1.0
# 275                               Tacos                    1.0
# 634                               Tacos                    1.0
# 553                               Tacos                    1.0
# 75                               Donuts                    1.0
# ..                                  ...                    ...
# 620                               Tacos                    0.0
# 21                               Donuts                    1.0
# 651                               Tacos                    1.0
# 56                                Tacos                    1.0
# 813                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 499            Freshman in College                         Night Person
# 275                 Not a Freshman                         Night Person
# 634            Freshman in College                         Night Person
# 553                 Not a Freshman                         Night Person
# 75             Freshman in College                         Night Person
# ..                             ...                                  ...
# 620            Freshman in College                       Morning Person
# 21                  Not a Freshman                       Morning Person
# 651            Freshman in College                         Night Person
# 56                  Not a Freshman                       Morning Person
# 813                 Not a Freshman                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 499                          Afternoon Person
# 275                          Afternoon Person
# 634                          Afternoon Person
# 553                            Morning Person
# 75                             Morning Person
# ..                                        ...
# 620                            Morning Person
# 21                             Morning Person
# 651                          Afternoon Person
# 56                           Afternoon Person
# 813                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 499                                         Illinois  ...
# 275                                         Illinois  ...
# 634                                         Illinois  ...
# 553                                         Illinois  ...
# 75                                          Illinois  ...
# ..                                               ...  ...
# 620                                         Illinois  ...
# 21                                      Out-of-state  ...
# 651                                         Illinois  ...
# 56                                          Illinois  ...
# 813                                         Illinois  ...
#
#     From 1 to 10, how happy are you right now?  \
# 499                                        8.0
# 275                                        4.0
# 634                                        7.0
# 553                                        8.0
# 75                                         8.0
# ..                                         ...
# 620                                        7.0
# 21                                         6.0
# 651                                        6.0
# 56                                         7.0
# 813                                        7.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 499                                           Moderate
# 275                                               Mild
# 634                                           Moderate
# 553                                               mild
# 75                                              Strong
# ..                                                 ...
# 620                                               Mild
# 21                                              strong
# 651                                           moderate
# 56                                              Strong
# 813                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 499                          Accounting + Data Science
# 275                                Information Science
# 634                           Gies College of Business
# 553                                                LAS
# 75                            Gies College of Business
# ..                                                 ...
# 620                                               Gies
# 21                                                 LAS
# 651                                   Computer Science
# 56                                                 LAS
# 813                                           I-School
#
#     What do you think is the hardest major at UIUC?  \
# 499                            Chemical Engineering
# 275                          Biomedical engineering
# 634                                         Physics
# 553                                             ece
# 75                                    Biochemistry
# ..                                              ...
# 620                                Computer Science
# 21                                               CS
# 651                                Computer Science
# 56                                      Engineering
# 813                            Computer Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 499                           R&B and Rap                             Khalid
# 275                               Hip-Hop                       TRAVIS SCOTT
# 634                         Mexican Music                      Fuerza Regida
# 553                                  jpop                                Eve
# 75                            House Music                       Lana Del Rey
# ..                                    ...                                ...
# 620                               Hip Hop                              Lucki
# 21                              pop music                       Taylor Swift
# 651                                   Rap                           Deftones
# 56                                   Jazz                             Laufey
# 813                                   Rap                         Kanye West
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 499                               Snapchat                          INI
# 275                                 TikTok                        I-N-I
# 634                                 Tiktok                          INI
# 553                                 tiktok                          INI
# 75                              Instagram                         I-N-I
# ..                                     ...                          ...
# 620                                      X                          INI
# 21                                  WeChat                          NIN
# 651                                 Tiktok                         Inoy
# 56                                 Tik Tok                   yes, I-N-I
# 813                               Snapchat                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 499                                         Mario Kart
# 275                                           Fortnite
# 634                               First Person Shooter
# 553                                     genshin impact
# 75                                           Monopoly
# ..                                                 ...
# 620                                         Basketball
# 21                                               NBA2K
# 651                                          Overwatch
# 56                                        Mario Kart 8
# 813                          Super Smash Bros Ultimate
#
#     What is your dream vacation location?
# 499                             Santorini
# 275                                 Japan
# 634                                 Paris
# 553                                 japan
# 75                                 Greece
# ..                                    ...
# 620                                 Tokyo
# 21                                 Hawaii
# 651                                 Japan
# 56                                  Japan
# 813                               Bahamas
#
# [482 rows x 178 columns]

# %% [markdown]
# ## Part 2.2: Select a Control Group
#
# Using the **exact same technique and syntax** as you did above, also select half (50%) of the participants to be in the control group.  Place them into a DataFrame called `control`. For now, it's okay if there are people who are in both groups.

# %%
control = df.sample(frac=0.5)
control
# Out:
#          Name Section Does your NetID ending with odd number or even number?  \
# 570     Elise     Y36                     NetID ends with an even number
# 241      Jeff     Y27                     NetID ends with an even number
# 594        JT     Y05                     NetID ends with an even number
# 46      Dylan     Y06                      NetID ends with an odd number
# 559     Danny     Y26                     NetID ends with an even number
# ..        ...     ...                                                ...
# 866      Sena     Y20                     NetID ends with an even number
# 675      Ryan     Y12                      NetID ends with an odd number
# 449  Shenjie      Y18                     NetID ends with an even number
# 131        Om     Y26                     NetID ends with an even number
# 349    Arthur     Y07                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 570                                              Heads
# 241                                              Tails
# 594                                              Tails
# 46                                               Heads
# 559                                              Heads
# ..                                                 ...
# 866                                              Heads
# 675                                              Heads
# 449                                              Tails
# 131                                              Heads
# 349                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 570                               Tacos                    1.0
# 241                              Donuts                    0.0
# 594                              Donuts                    0.0
# 46                                Tacos                    1.0
# 559                               Tacos                    1.0
# ..                                  ...                    ...
# 866                              Donuts                    0.0
# 675                              Donuts                    1.0
# 449                              Donuts                    0.0
# 131                               Tacos                    0.0
# 349                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 570            Freshman in College                       Morning Person
# 241            Freshman in College                         Night Person
# 594            Freshman in College                         Night Person
# 46                  Not a Freshman                         Night Person
# 559            Freshman in College                         Night Person
# ..                             ...                                  ...
# 866            Freshman in College                         Night Person
# 675            Freshman in College                         Night Person
# 449            Freshman in College                         Night Person
# 131            Freshman in College                         Night Person
# 349                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 570                          Afternoon Person
# 241                          Afternoon Person
# 594                          Afternoon Person
# 46                           Afternoon Person
# 559                          Afternoon Person
# ..                                        ...
# 866                          Afternoon Person
# 675                          Afternoon Person
# 449                          Afternoon Person
# 131                          Afternoon Person
# 349                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 570                                         Illinois  ...
# 241                                     Out-of-state  ...
# 594                                         Illinois  ...
# 46                                      Out-of-state  ...
# 559                                         Illinois  ...
# ..                                               ...  ...
# 866                                         Illinois  ...
# 675                                         Illinois  ...
# 449                                     Out-of-state  ...
# 131                                         Illinois  ...
# 349                                     Out-of-state  ...
#
#     From 1 to 10, how happy are you right now?  \
# 570                                        6.0
# 241                                        8.9
# 594                                        6.0
# 46                                         5.0
# 559                                        7.0
# ..                                         ...
# 866                                        8.0
# 675                                        5.0
# 449                                        7.0
# 131                                        9.0
# 349                                        6.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 570                                               mild
# 241                                             strong
# 594                                               Mild
# 46                                              Strong
# 559                                             Strong
# ..                                                 ...
# 866                                               mild
# 675                                             strong
# 449                                               mild
# 131                                            Extreme
# 349                                           Moderate
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 570                                               Gies
# 241                           Gies College of Business
# 594                                               Gies
# 46                                                  IS
# 559                                Business Undeclared
# ..                                                 ...
# 866                               computer engineering
# 675                                               Gies
# 449                                                LAS
# 131                                       Computer Eng
# 349                                            Ischool
#
#     What do you think is the hardest major at UIUC?  \
# 570                             nuclear engineering
# 241                                Computer Science
# 594                           Aerospace Engineering
# 46                                               CS
# 559                                Computer Science
# ..                                              ...
# 866                            computer engineering
# 675                                        Bio Chem
# 449                              English Literature
# 131                                         Physics
# 349                                              Cs
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 570                                  rock                              Drake
# 241             Pop/A little bit of Indie               Jason Derulo or ABBA
# 594                            Everything                            J. Cole
# 46                       Modern Dream Pop                          familypet
# 559                                   RNB                         Bruno Mars
# ..                                    ...                                ...
# 866                         turkish music                       Edis Görgülü
# 675                                   Rap                       Playboi Cart
# 449                                   NaN                                NaN
# 131                                   Rap                               $not
# 349                                   Rnb                              Drake
#
#     What's your favorite social media app?  \
# 570                               snapchat
# 241                              Instagram
# 594                              Instagram
# 46                               Instagram
# 559                                 Tiktok
# ..                                     ...
# 866                              instagram
# 675                                   Snap
# 449                                 Wechat
# 131                                      X
# 349                               Whatsapp
#
#            How do you respond to I-L-L?  \
# 570                               I-N-I
# 241  I do not understand this question.
# 594                               I-N-I
# 46                             Illinois
# 559                                 INI
# ..                                  ...
# 866                               I-N-I
# 675                                 INI
# 449                                 NaN
# 131                                 INI
# 349                                 Ini
#
#     What is your favorite game to play (either video game or IRL)?  \
# 570                                         Volleyball
# 241                                             Tennis
# 594                                        Overwatch 2
# 46                            Forza Horizon/Motorsport
# 559                                  League of Legends
# ..                                                 ...
# 866                                              zelda
# 675                                    Rainbow 6 Seige
# 449                                      Project Sekai
# 131                                  Rainbow Six Siege
# 349                                                Gta
#
#     What is your dream vacation location?
# 570                                 Spain
# 241                    The Slavic region
# 594                           Switzerland
# 46                                  Italy
# 559                              Bahamas
# ..                                    ...
# 866                        Bordum, Turkey
# 675                                 Italy
# 449                                 Tokyo
# 131                                  Bali
# 349                                 Japan
#
# [482 rows x 178 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( len(treatment) == len(control) ), "The `treatment` and `control` groups must be the same size."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`"
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`"


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Overlapping Selection?
#
# The following code will detect rows that are **both in your treatment and control** groups.
#
# Run the following cell to see everyone who is in both groups:

# %%
df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]
# Out:
#                        Name Section  \
# 12                     Ryan     Y30
# 21                   Jayden     Y36
# 25                     Noam     Y10
# 31                    Sarah     Y09
# 40                      Kai     Y06
# ..                      ...     ...
# 949                Vihaansh     Y08
# 950                  Albert     Y02
# 952                    Erin     Y29
# 958                  Hanle      Y12
# 960  Mohammed Fatheen Ahmed     Y22
#
#     Does your NetID ending with odd number or even number?  \
# 12                      NetID ends with an even number
# 21                       NetID ends with an odd number
# 25                                                 NaN
# 31                       NetID ends with an odd number
# 40                      NetID ends with an even number
# ..                                                 ...
# 949                      NetID ends with an odd number
# 950                     NetID ends with an even number
# 952                      NetID ends with an odd number
# 958                     NetID ends with an even number
# 960                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 12                                               Heads
# 21                                               Heads
# 25                                               Tails
# 31                                               Heads
# 40                                               Tails
# ..                                                 ...
# 949                                              Heads
# 950                                              Tails
# 952                                              Heads
# 958                                              Heads
# 960                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 12                               Donuts                    0.0
# 21                               Donuts                    1.0
# 25                                Tacos                    1.0
# 31                               Donuts                    0.0
# 40                               Donuts                    1.0
# ..                                  ...                    ...
# 949                               Tacos                    1.0
# 950                               Tacos                    1.0
# 952                               Tacos                    1.0
# 958                              Donuts                    0.0
# 960                              Donuts                    0.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 12             Freshman in College                         Night Person
# 21                  Not a Freshman                       Morning Person
# 25             Freshman in College                       Morning Person
# 31                  Not a Freshman                         Night Person
# 40                  Not a Freshman                         Night Person
# ..                             ...                                  ...
# 949                 Not a Freshman                         Night Person
# 950            Freshman in College                         Night Person
# 952            Freshman in College                       Morning Person
# 958                 Not a Freshman                         Night Person
# 960            Freshman in College                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 12                           Afternoon Person
# 21                             Morning Person
# 25                             Morning Person
# 31                           Afternoon Person
# 40                           Afternoon Person
# ..                                        ...
# 949                          Afternoon Person
# 950                          Afternoon Person
# 952                          Afternoon Person
# 958                          Afternoon Person
# 960                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 12                                          Illinois  ...
# 21                                      Out-of-state  ...
# 25                                          Illinois  ...
# 31                                          Illinois  ...
# 40                                      Out-of-state  ...
# ..                                               ...  ...
# 949                                     Out-of-state  ...
# 950                                         Illinois  ...
# 952                                         Illinois  ...
# 958                                     Out-of-state  ...
# 960                                         Illinois  ...
#
#     From 1 to 10, how happy are you right now?  \
# 12                                        10.0
# 21                                         6.0
# 25                                         4.0
# 31                                         9.0
# 40                                         8.0
# ..                                         ...
# 949                                        7.0
# 950                                        7.0
# 952                                        6.0
# 958                                        6.0
# 960                                        3.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 12                                            Moderate
# 21                                              strong
# 25                                            Moderate
# 31                                              Strong
# 40                                            Moderate
# ..                                                 ...
# 949                                            Extreme
# 950                                             strong
# 952                                             strong
# 958                                             strong
# 960                                             strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 12                                                 LAS
# 21                                                 LAS
# 25                                                Gies
# 31                                                 LAS
# 40                                                  CS
# ..                                                 ...
# 949                               Computer Engineering
# 950                                                DgS
# 952                                               UIUC
# 958                                               Gies
# 960                                                las
#
#     What do you think is the hardest major at UIUC?  \
# 12                                          Physics
# 21                                               CS
# 25                                         Physics
# 31                                          Physics
# 40                                Material engineer
# ..                                              ...
# 949                          Electrical Engineering
# 950                                       Chemistry
# 952                                              CS
# 958                                             ECE
# 960                                              CS
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 12                                   Rock               Two Door Cinema Club
# 21                              pop music                       Taylor Swift
# 25                     Pop/Indie Folk/Rap                      Taylor Swift!
# 31                                    Pop                           Doja Cat
# 40                                    pop                           Coldplay
# ..                                    ...                                ...
# 949                                  Rock                             Eminem
# 950                                   rap                        purity ring
# 952          R&B, Indie music, pop, K-pop                       Shawn Mendes
# 958                                   All                        Post Malone
# 960                                   rap                              Drake
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 12                                 youtube                  **silence**
# 21                                  WeChat                          NIN
# 25                               Instagram                        I-N-I
# 31                                 Tik Tok                        I-N-I
# 40                                 Discord                          IOI
# ..                                     ...                          ...
# 949                              Instagram                        I-N-I
# 950                              INStagram                          INI
# 952                              instagram                        I-N-I
# 958                                twitter                          ill
# 960                                   Snap                         ini
#
#     What is your favorite game to play (either video game or IRL)?  \
# 12                                          Overcooked
# 21                                               NBA2K
# 25                                               FIFA
# 31                                        Overcooked 2
# 40                                         Apex Legend
# ..                                                 ...
# 949                                             Soccer
# 950                                              Chess
# 952                                                IRL
# 958                                  Rainbow six siege
# 960                                       apex legends
#
#     What is your dream vacation location?
# 12              Grand Teton National Park
# 21                                 Hawaii
# 25                            South Korea
# 31                                Bahamas
# 40                            New Zealand
# ..                                    ...
# 949                                Norway
# 950                            California
# 952                              New York
# 958                       Japan, Hokkaido
# 960                                europe
#
# [230 rows x 178 columns]

# %% [markdown]
# **Q: Why would your code result in some people being included in both groups? Write at least one complete sentence explaining why you think this might occur.**

# %% [markdown]
# This occurs because our code df.sample(frac=0.5) will randomly sample 50% of the people in our dataset, regardless of whether or not they've been previously picked.

# %% [markdown]
# ## Part 2.3:
#
# Read the following guide on **using `.index.isin` to select all rows from a DataFrame not in another DataFrame**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-isin-selection/
#
# Finally, create a new `control` group that contains all of the participants from `df` that are not in `treatment`:

# %%
control = df[ ~df.index.isin(treatment.index)]
control
# Out:
#            Name Section  \
# 1    Prof. Wade  L1, L2
# 4        Ayden      Y14
# 5          Sens     Y30
# 6         Suvan     Y22
# 8         Sarah     Y36
# ..          ...     ...
# 957     Arseniy     Y20
# 959        Zoe      Y19
# 962       Nyssa     Y23
# 963      maddax      Y2
# 964  CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 1                                                  NaN
# 4                       NetID ends with an even number
# 5                       NetID ends with an even number
# 6                       NetID ends with an even number
# 8                        NetID ends with an odd number
# ..                                                 ...
# 957                                                NaN
# 959                     NetID ends with an even number
# 962                      NetID ends with an odd number
# 963                      NetID ends with an odd number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 1                                                Heads
# 4                                                Heads
# 5                                                Heads
# 6                                                Heads
# 8                                                Heads
# ..                                                 ...
# 957                                              Heads
# 959                                              Heads
# 962                                              Heads
# 963                                              Tails
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 1                                 Tacos                    1.0
# 4                                Donuts                    1.0
# 5                                 Tacos                    1.0
# 6                                Donuts                    1.0
# 8                                Donuts                    0.0
# ..                                  ...                    ...
# 957                               Tacos                    1.0
# 959                               Tacos                    1.0
# 962                               Tacos                    1.0
# 963                               Tacos                    0.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 1                   Not a Freshman                         Night Person
# 4              Freshman in College                         Night Person
# 5              Freshman in College                         Night Person
# 6              Freshman in College                         Night Person
# 8              Freshman in College                       Morning Person
# ..                             ...                                  ...
# 957                 Not a Freshman                         Night Person
# 959            Freshman in College                         Night Person
# 962            Freshman in College                         Night Person
# 963            Freshman in College                         Night Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 1                            Afternoon Person
# 4                              Morning Person
# 5                              Morning Person
# 6                            Afternoon Person
# 8                              Morning Person
# ..                                        ...
# 957                          Afternoon Person
# 959                          Afternoon Person
# 962                          Afternoon Person
# 963                          Afternoon Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 1                                                NaN  ...
# 4                                           Illinois  ...
# 5                                           Illinois  ...
# 6                                           Illinois  ...
# 8                                           Illinois  ...
# ..                                               ...  ...
# 957                                     Out-of-state  ...
# 959                                         Illinois  ...
# 962                                         Illinois  ...
# 963                                         Illinois  ...
# 964                                     Out-of-state  ...
#
#     From 1 to 10, how happy are you right now?  \
# 1                                         8.25
# 4                                         8.00
# 5                                         8.00
# 6                                         5.00
# 8                                         7.00
# ..                                         ...
# 957                                       7.00
# 959                                       7.00
# 962                                       8.00
# 963                                       1.00
# 964                                       8.00
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 1                                             Moderate
# 4                                               Strong
# 5                                             Moderate
# 6                                               Strong
# 8                                               Strong
# ..                                                 ...
# 957                                           moderate
# 959                                          Moderate
# 962                                               mild
# 963                                            extreme
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 1                                             Grainger
# 4                                                 Gies
# 5                                     Grainger and LAS
# 6                      Statistics and Computer Science
# 8                                              iSchool
# ..                                                 ...
# 957                                                NaN
# 959                              School of Information
# 962                                                las
# 963                          finance with data science
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 1                                           Physics
# 4                                   Any engineering
# 5                                               ECE
# 6                              Computer Engineering
# 8                                  Computer Science
# ..                                              ...
# 957                                             NaN
# 959                          Molecular engineering
# 962                                             ece
# 963                                         general
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 1                             Pop and EDM                       Taylor Swift
# 4                               Indie pop                      The Lumineers
# 5                                Shoegaze                        Fiona Apple
# 6                                 Hip hop                        Don toliver
# 8                                   Indie                       Taylor Swift
# ..                                    ...                                ...
# 957                                   NaN                                NaN
# 959   Everything (pop, R&B, rap, country)                      Taylor Swift
# 962                                   pop                       taylor swift
# 963                                   rap                       lil uzi vert
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 1                                  YouTube                        I-N-I
# 4                                 Snapchat                          INI
# 5                                  Twitter                        I-N-I
# 6                                   Tiktok                         Ini
# 8                                Instagram                        I-N-I
# ..                                     ...                          ...
# 957                                    NaN                        I-N-I
# 959                                Tiktok                        I-N-I!
# 962                                twitter                          INI
# 963                               snapchat                          ini
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 1                                             Factorio
# 4                                           Basketball
# 5                                            Fall Guys
# 6                                         20 questions
# 8                                                  Uno
# ..                                                 ...
# 957                                                NaN
# 959                                   Street Fighters
# 962                                         code names
# 963                                        quiet game
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 1                               Mountains
# 4                              Australia
# 5                                      PR
# 6                             Switzerland
# 8                                  Taiwan
# ..                                    ...
# 957                        Moscow, Russia
# 959                               Greece
# 962                                greece
# 963                    middle of nowhere
# 964                                 Korea
#
# [483 rows x 178 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`"
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`"
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 2.4: Finding Yourself!
#
# Use the following cells to write Python code to find yourself in either the treatment group or control group.
# - **Hint**: How do you select a subset of rows?  What conditional will identify you??
# - If you did not fill out the "Hello Survey" then you are not in this dataset. :(
# - If you are not in this survey, find either "Prof. Wade" or "Prof. Karle" instead.  *(Those are the names we used in the `Name` column.)*

# %%
# Use this cell to find yourself in either `treatment` or `control` groups:
# ...feel free to add extra "Code" cells here if needed.

#*****I filled out the survey but for some reason I can't find myself in this dataset no matter how many times I type my name or try various typos in my name. I also did this survey before the due date so I'm really not sure why I can't find myself***
df_me = df[(df.Name == "Prof. Wade") & (df.index.isin(control.index))]
df_me
# Out:
#          Name Section Does your NetID ending with odd number or even number?  \
# 1  Prof. Wade  L1, L2                                                NaN
#
#   If I flipped a coin, do you think it would it land on heads or tails?  \
# 1                                              Heads
#
#   Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 1                               Tacos                    1.0
#
#   Are you a freshman in college? Are you a morning or a night person?  \
# 1                 Not a Freshman                         Night Person
#
#   Are you a morning or an afternoon person?  \
# 1                          Afternoon Person
#
#   Are you a student from Illinois or out-of-state?  ...  \
# 1                                              NaN  ...
#
#   From 1 to 10, how happy are you right now?  \
# 1                                       8.25
#
#   The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 1                                           Moderate
#
#   What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 1                                           Grainger
#
#   What do you think is the hardest major at UIUC?  \
# 1                                         Physics
#
#   What genre of music do you listen to? Who is your favorite music artist?  \
# 1                           Pop and EDM                       Taylor Swift
#
#   What's your favorite social media app? How do you respond to I-L-L?  \
# 1                                YouTube                        I-N-I
#
#   What is your favorite game to play (either video game or IRL)?  \
# 1                                           Factorio
#
#   What is your dream vacation location?
# 1                             Mountains
#
# [1 rows x 178 columns]

# %% [markdown]
# ## Analysis: Finding Yourself!
#
# **Q: Which group where you in -- treatment or control?**

# %% [markdown]
# Professor Wade is in the control group.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Using Blocking to Create Treatment and Control Groups that are Balanced
#
# In your pre-experiment research, you have reason to believe that how the participants answer **your group's question** might influence the response of this experiment!  Oh no! Even though this is a large sample of participants, we want to block to be absolutely sure that the treatment and control groups are balanced with regard to your group's question!
#
# To control for this, we will using **blocking**!  Remember from lecture that blocking refers to creating subgroups for each response, selecting equal-sized treatment and control groups from each block, and then combining all the treatment groups together and all the control groups together to get the final groups. This ensures that your groups are balanced with regard to the variable you blocked on!
#
# You have already done some of this work:
# - Earlier in this notebook, you created `df1` that includes everyone who answered your group's question one way.
# - Earlier in this notebook, you created `df2` that includes everyone who answered your group's question the other way.

# %% [markdown]
# ## Part 3.1:
#
# Create a `df1_treatment` group that contains a random selection of 50% of the rows from `df1`.

# %%
df1_treatment = df1.sample(frac=0.5)
df1_treatment
# Out:
#         Name Section Does your NetID ending with odd number or even number?  \
# 631    Ginny     Y24                      NetID ends with an odd number
# 622     Alan     Y35                     NetID ends with an even number
# 591  Utkarsh     Y41                      NetID ends with an odd number
# 706    Ziyao     Y35                      NetID ends with an odd number
# 315      Tia     Y09                      NetID ends with an odd number
# ..       ...     ...                                                ...
# 617    Arpit     Y35                     NetID ends with an even number
# 338     Ansh     Y15                     NetID ends with an even number
# 266   Simran     Y03                      NetID ends with an odd number
# 959     Zoe      Y19                     NetID ends with an even number
# 948    Iris      Y06                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 631                                              Heads
# 622                                              Heads
# 591                                              Tails
# 706                                              Heads
# 315                                              Tails
# ..                                                 ...
# 617                                              Heads
# 338                                              Heads
# 266                                              Heads
# 959                                              Heads
# 948                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 631                               Tacos                    1.0
# 622                               Tacos                    1.0
# 591                              Donuts                    1.0
# 706                               Tacos                    0.0
# 315                               Tacos                    1.0
# ..                                  ...                    ...
# 617                              Donuts                    1.0
# 338                               Tacos                    0.0
# 266                               Tacos                    1.0
# 959                               Tacos                    1.0
# 948                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 631            Freshman in College                       Morning Person
# 622            Freshman in College                         Night Person
# 591            Freshman in College                         Night Person
# 706            Freshman in College                         Night Person
# 315            Freshman in College                       Morning Person
# ..                             ...                                  ...
# 617                 Not a Freshman                       Morning Person
# 338                 Not a Freshman                         Night Person
# 266                 Not a Freshman                         Night Person
# 959            Freshman in College                         Night Person
# 948                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 631                            Morning Person
# 622                          Afternoon Person
# 591                            Morning Person
# 706                          Afternoon Person
# 315                          Afternoon Person
# ..                                        ...
# 617                            Morning Person
# 338                          Afternoon Person
# 266                          Afternoon Person
# 959                          Afternoon Person
# 948                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 631                                     Out-of-state  ...
# 622                                         Illinois  ...
# 591                                     Out-of-state  ...
# 706                                     Out-of-state  ...
# 315                                     Out-of-state  ...
# ..                                               ...  ...
# 617                                     Out-of-state  ...
# 338                                         Illinois  ...
# 266                                     Out-of-state  ...
# 959                                         Illinois  ...
# 948                                         Illinois  ...
#
#     From 1 to 10, how happy are you right now?  \
# 631                                        7.0
# 622                                        8.0
# 591                                        7.0
# 706                                        6.0
# 315                                        7.0
# ..                                         ...
# 617                                       10.0
# 338                                        7.0
# 266                                       10.0
# 959                                        7.0
# 948                                        NaN
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 631                                               mild
# 622                                           moderate
# 591                                            extreme
# 706                                               mild
# 315                                           moderate
# ..                                                 ...
# 617                                             Strong
# 338                                            Extreme
# 266                                           Moderate
# 959                                          Moderate
# 948                                                NaN
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 631                                              Math.
# 622                                               Gies
# 591                                                LAS
# 706                             electrical engineering
# 315                                                LAS
# ..                                                 ...
# 617                                           Grainger
# 338                                                LAS
# 266                                                LAS
# 959                              School of Information
# 948                                                NaN
#
#     What do you think is the hardest major at UIUC?  \
# 631                               computer science.
# 622                                Bio Engineering
# 591                          Astronomy+Data Science
# 706                                              CS
# 315                                         physics
# ..                                              ...
# 617                                             ECE
# 338                                        Comp Sci
# 266                                    Biochemistry
# 959                          Molecular engineering
# 948                                             NaN
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 631                                   Pop                       Taylor Swift
# 622                           Pop/Rap/EDM                       Frank Ocean
# 591                          Taylor Swift                       Taylor Swift
# 706                           Vapour wave                           Jay Chou
# 315                                  kpop                              ateez
# ..                                    ...                                ...
# 617                            Slow Hindi                       Arijit Singh
# 338                               Hip-Hop                             J.Cole
# 266                                   Pop                              Drake
# 959   Everything (pop, R&B, rap, country)                      Taylor Swift
# 948                                   NaN                                NaN
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 631                                 wechat                     It's ok.
# 622                             Instagram                         I-N-I
# 591                                Youtube                       I-N-I!
# 706                                 wechat                         none
# 315                              instagram                        i-n-i
# ..                                     ...                          ...
# 617                              Instagram                          INI
# 338                              Instagram                          INI
# 266                                 TikTok                        I-N-I
# 959                                Tiktok                        I-N-I!
# 948                                    NaN                          NaN
#
#     What is your favorite game to play (either video game or IRL)?  \
# 631                               Talking Tom gold run
# 622                                            Hockey
# 591                                              Chess
# 706                                                IRL
# 315                                             spades
# ..                                                 ...
# 617                                 Depends on my mood
# 338                                  Rainbow Six Siege
# 266                                     Subway Surfers
# 959                                   Street Fighters
# 948                                                NaN
#
#     What is your dream vacation location?
# 631                            California
# 622                               Greece
# 591                              Maldives
# 706                               Iceland
# 315                                 india
# ..                                    ...
# 617                              Maldives
# 338                           Switzerland
# 266                                Greece
# 959                               Greece
# 948                                   NaN
#
# [378 rows x 178 columns]

# %% [markdown]
# ## Part 3.2:
#
# Create a `df1_control` group that contains the other half of the rows from `df1`. *(You can refer back to Part 2 to refresh on how to do this, make sure you use `df1` and `df1_control` as your DataFrames.)*

# %%
df1_control = df1[ ~df1.index.isin(df1_treatment.index)]
df1_control
# Out:
#                        Name Section  \
# 0               Prof. Karle  L1, L2
# 7                Joseph Kim     Y16
# 15                  Michael     Y03
# 17                   Chuyan     Y24
# 19                   Lauren     Y03
# ..                      ...     ...
# 955                lijiajin     Y01
# 958                  Hanle      Y12
# 960  Mohammed Fatheen Ahmed     Y22
# 963                  maddax      Y2
# 964              CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 7                       NetID ends with an even number
# 15                      NetID ends with an even number
# 17                      NetID ends with an even number
# 19                      NetID ends with an even number
# ..                                                 ...
# 955                      NetID ends with an odd number
# 958                     NetID ends with an even number
# 960                      NetID ends with an odd number
# 963                      NetID ends with an odd number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 7                                                Heads
# 15                                               Heads
# 17                                               Heads
# 19                                               Heads
# ..                                                 ...
# 955                                              Heads
# 958                                              Heads
# 960                                              Heads
# 963                                              Tails
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 7                                Donuts                    1.0
# 15                                Tacos                    0.0
# 17                               Donuts                    0.0
# 19                                Tacos                    0.0
# ..                                  ...                    ...
# 955                              Donuts                    0.0
# 958                              Donuts                    0.0
# 960                              Donuts                    0.0
# 963                               Tacos                    0.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 7                   Not a Freshman                         Night Person
# 15                  Not a Freshman                         Night Person
# 17             Freshman in College                         Night Person
# 19                  Not a Freshman                         Night Person
# ..                             ...                                  ...
# 955                 Not a Freshman                         Night Person
# 958                 Not a Freshman                         Night Person
# 960            Freshman in College                       Morning Person
# 963            Freshman in College                         Night Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 7                            Afternoon Person
# 15                           Afternoon Person
# 17                           Afternoon Person
# 19                             Morning Person
# ..                                        ...
# 955                            Morning Person
# 958                          Afternoon Person
# 960                            Morning Person
# 963                          Afternoon Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 7                                           Illinois  ...
# 15                                          Illinois  ...
# 17                                      Out-of-state  ...
# 19                                          Illinois  ...
# ..                                               ...  ...
# 955                                     Out-of-state  ...
# 958                                     Out-of-state  ...
# 960                                         Illinois  ...
# 963                                         Illinois  ...
# 964                                     Out-of-state  ...
#
#     From 1 to 10, how happy are you right now?  \
# 0                                          9.0
# 7                                          4.0
# 15                                        10.0
# 17                                         7.0
# 19                                         8.0
# ..                                         ...
# 955                                        5.0
# 958                                        6.0
# 960                                        3.0
# 963                                        1.0
# 964                                        8.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 7                                                 Mild
# 15                                             Extreme
# 17                                             extreme
# 19                                             Strong
# ..                                                 ...
# 955                                             strong
# 958                                             strong
# 960                                             strong
# 963                                            extreme
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 7                                                  LAS
# 15                                                 LAS
# 17                                            business
# 19                                                 LAS
# ..                                                 ...
# 955                                                 cs
# 958                                               Gies
# 960                                                las
# 963                          finance with data science
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 7                                  Computer Science
# 15                           Electrical Engineering
# 17                                               CS
# 19                                     Engineering
# ..                                              ...
# 955                                              cs
# 958                                             ECE
# 960                                              CS
# 963                                         general
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 7                              soundtrack             Ski Mask the Slump God
# 15                             Indie rock                           Pavement
# 17                                    R&B                           Jay Chou
# 19                                    All                                N/a
# ..                                    ...                                ...
# 955                                   sad                           Lana Ray
# 958                                   All                        Post Malone
# 960                                   rap                              Drake
# 963                                   rap                       lil uzi vert
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 7                                Instagram                    I-N-O-I-S
# 15                               Instagram                        I-N-I
# 17                                  Wechat                    Illinois?
# 19                                 Tik Tok                        I-N-I
# ..                                     ...                          ...
# 955                                    ins                        I-N-N
# 958                                twitter                          ill
# 960                                   Snap                         ini
# 963                               snapchat                          ini
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 7    Super Smash Bros. Ultimate (Dear Karle and Wad...
# 15                                            Baseball
# 17                                                none
# 19                                                 N/a
# ..                                                 ...
# 955                                           valorant
# 958                                  Rainbow six siege
# 960                                       apex legends
# 963                                        quiet game
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 0                            The Maldives
# 7                                 Nowhere
# 15                                 France
# 17         travel with friends and family
# 19                                  Japan
# ..                                    ...
# 955                               finland
# 958                       Japan, Hokkaido
# 960                                europe
# 963                    middle of nowhere
# 964                                 Korea
#
# [377 rows x 178 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df1_treatment' in vars() ), "You do not have a DataFrame called `df1_treatment`."
assert( 'df1_control' in vars() ), "You do not have a DataFrame called `df1_control`."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df1_control.index) ]) == 0), "The `df1_treatment` and `df1_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df2.index) ]) == 0), "The `df1_treatment` and `df2` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_control.index) & df.index.isin(df2.index) ]) == 0), "The `df1_control` and `df2` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.3:
#
# Create a `df2_treatment` group that contains a random selection of 50% of the rows from `df2`.

# %%
df2_treatment = df2.sample(frac=0.5)
df2_treatment
# Out:
#         Name Section Does your NetID ending with odd number or even number?  \
# 289     Sean     Y13                     NetID ends with an even number
# 648     Jack     Y25                     NetID ends with an even number
# 209    Ramiz     Y16                     NetID ends with an even number
# 472     Emin     Y25                      NetID ends with an odd number
# 575     Zion     Y01                     NetID ends with an even number
# ..       ...     ...                                                ...
# 406    James     Y22                      NetID ends with an odd number
# 55      Meng     Y08                      NetID ends with an odd number
# 677     Alex     Y24                     NetID ends with an even number
# 542     Reva     Y04                      NetID ends with an odd number
# 431  Matthew     Y22                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 289                                              Heads
# 648                                              Heads
# 209                                              Tails
# 472                                              Heads
# 575                                              Heads
# ..                                                 ...
# 406                                              Heads
# 55                                               Tails
# 677                                              Heads
# 542                                              Tails
# 431                                              Tails
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 289                              Donuts                    1.0
# 648                              Donuts                    1.0
# 209                               Tacos                    1.0
# 472                               Tacos                    1.0
# 575                               Tacos                    1.0
# ..                                  ...                    ...
# 406                              Donuts                    0.0
# 55                                Tacos                    0.0
# 677                               Tacos                    1.0
# 542                               Tacos                    0.0
# 431                              Donuts                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 289                 Not a Freshman                         Night Person
# 648            Freshman in College                       Morning Person
# 209                 Not a Freshman                         Night Person
# 472            Freshman in College                       Morning Person
# 575                 Not a Freshman                         Night Person
# ..                             ...                                  ...
# 406            Freshman in College                         Night Person
# 55             Freshman in College                       Morning Person
# 677            Freshman in College                         Night Person
# 542                 Not a Freshman                         Night Person
# 431            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 289                          Afternoon Person
# 648                            Morning Person
# 209                            Morning Person
# 472                            Morning Person
# 575                          Afternoon Person
# ..                                        ...
# 406                          Afternoon Person
# 55                             Morning Person
# 677                          Afternoon Person
# 542                          Afternoon Person
# 431                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 289                                     Out-of-state  ...
# 648                                     Out-of-state  ...
# 209                                         Illinois  ...
# 472                                         Illinois  ...
# 575                                         Illinois  ...
# ..                                               ...  ...
# 406                                         Illinois  ...
# 55                                          Illinois  ...
# 677                                         Illinois  ...
# 542                                         Illinois  ...
# 431                                         Illinois  ...
#
#     From 1 to 10, how happy are you right now?  \
# 289                                        7.0
# 648                                        1.0
# 209                                        8.0
# 472                                        6.0
# 575                                        6.0
# ..                                         ...
# 406                                        7.0
# 55                                         1.0
# 677                                        5.0
# 542                                        5.0
# 431                                        8.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 289                                           moderate
# 648                                                NaN
# 209                                             Strong
# 472                                              Mild
# 575                                           moderate
# ..                                                 ...
# 406                                               Mild
# 55                                                none
# 677                                             Strong
# 542                                           moderate
# 431                                                NaN
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 289                                          IS + Stat
# 648                                                LAS
# 209                                            Biology
# 472                                               Gies
# 575                                                LAS
# ..                                                 ...
# 406                                           Business
# 55                                    computer science
# 677                                               Gies
# 542                                                LAS
# 431                                                LAS
#
#     What do you think is the hardest major at UIUC?  \
# 289                                              CS
# 648                                         Physics
# 209                           Aerospace engineering
# 472                                              CS
# 575                             Nuclear Engineering
# ..                                              ...
# 406                            Computer Engineering
# 55                                              ECE
# 677                                         Physics
# 542                          Biomedical engineering
# 431                           Aerospace Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 289                         Pop, rap, R&B                           Jay Chou
# 648                                   NaN                                NaN
# 209                                   Pop                      Ariana Grande
# 472                               Hip-hop                          Pop smoke
# 575                             Reggaeton                          Bad Bunny
# ..                                    ...                                ...
# 406                               Country                     Zac Brown Band
# 55                                    R&B                       taylor swift
# 677                                  Rock                          Radiohead
# 542                                   pop                           Doja cat
# 431                               Country                      Kenny Chesney
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 289                                 wechat              illini/illinois
# 648                                 Wechat                          NaN
# 209                               Snapchat                          INI
# 472                              Instagram                        I-N-I
# 575                                 Reddit                        I-N-I
# ..                                     ...                          ...
# 406                              Instagram                        I-N-I
# 55                                     ins                    dont know
# 677                                Discord                        I-N-I
# 542                                 Tiktok                        I-N-I
# 431                               Snapchat                        I-N-I
#
#     What is your favorite game to play (either video game or IRL)?  \
# 289                                                LOL
# 648                            Football Manager Series
# 209                                      Baldur Gate 3
# 472                                               Fifa
# 575                                  Fallout New Vegas
# ..                                                 ...
# 406                                           Football
# 55                                                none
# 677                                    Baldur's Gate 3
# 542                                      Monopoly deal
# 431                                         Basketball
#
#     What is your dream vacation location?
# 289                               Iceland
# 648                      Barcelona, Spain
# 209                                Hawaii
# 472                               Hawaii
# 575                           Puerto Rico
# ..                                    ...
# 406                                Alaska
# 55                                iceland
# 677                        St. Petersburg
# 542                               Greece
# 431                                Hawaii
#
# [92 rows x 178 columns]

# %% [markdown]
# ## Part 3.4:
#
# Create a `df2_control` group that contains the other half of the rows from `df2`.

# %%
df2_control = df2[~df2.index.isin(df2_treatment.index)]
df2_control
# Out:
#         Name Section Does your NetID ending with odd number or even number?  \
# 11     Finch     Y03                     NetID ends with an even number
# 20     Eric      Y10                      NetID ends with an odd number
# 29      Josh     Y21                     NetID ends with an even number
# 53   Binchao     Y30                     NetID ends with an even number
# 70   Christy     Y18                     NetID ends with an even number
# ..       ...     ...                                                ...
# 907  Tarina     Y20                       NetID ends with an odd number
# 909      Ben     Y29                      NetID ends with an odd number
# 919     Kate     Y13                     NetID ends with an even number
# 920  Yamuna      Y34                      NetID ends with an odd number
# 961    Peter     Y09                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 11                                               Tails
# 20                                               Heads
# 29                                               Tails
# 53                                               Heads
# 70                                               Heads
# ..                                                 ...
# 907                                              Heads
# 909                                              Tails
# 919                                              Tails
# 920                                              Tails
# 961                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 11                               Donuts                    0.0
# 20                                Tacos                    1.0
# 29                                Tacos                    1.0
# 53                               Donuts                    1.0
# 70                                Tacos                    1.0
# ..                                  ...                    ...
# 907                               Tacos                    1.0
# 909                               Tacos                    0.0
# 919                               Tacos                    1.0
# 920                               Tacos                    1.0
# 961                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 11                  Not a Freshman                       Morning Person
# 20             Freshman in College                         Night Person
# 29             Freshman in College                         Night Person
# 53             Freshman in College                         Night Person
# 70                  Not a Freshman                       Morning Person
# ..                             ...                                  ...
# 907            Freshman in College                         Night Person
# 909            Freshman in College                         Night Person
# 919                 Not a Freshman                       Morning Person
# 920            Freshman in College                         Night Person
# 961                 Not a Freshman                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 11                             Morning Person
# 20                           Afternoon Person
# 29                           Afternoon Person
# 53                             Morning Person
# 70                             Morning Person
# ..                                        ...
# 907                          Afternoon Person
# 909                          Afternoon Person
# 919                            Morning Person
# 920                          Afternoon Person
# 961                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 11                                          Illinois  ...
# 20                                          Illinois  ...
# 29                                          Illinois  ...
# 53                                      Out-of-state  ...
# 70                                          Illinois  ...
# ..                                               ...  ...
# 907                                         Illinois  ...
# 909                                         Illinois  ...
# 919                                         Illinois  ...
# 920                                         Illinois  ...
# 961                                     Out-of-state  ...
#
#     From 1 to 10, how happy are you right now?  \
# 11                                         1.0
# 20                                         6.0
# 29                                         8.0
# 53                                         7.0
# 70                                         5.0
# ..                                         ...
# 907                                        8.0
# 909                                        8.0
# 919                                        9.0
# 920                                       10.0
# 961                                        5.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 11                                                 NaN
# 20                                           Moderate
# 29                                                Mild
# 53                                                mild
# 70                                            Moderate
# ..                                                 ...
# 907                                             strong
# 909                                               Mild
# 919                                           Moderate
# 920                                             strong
# 961                                             strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 11                                    College of Media
# 20                                         Accounting
# 29                                                Geis
# 53                                            Grainger
# 70                                             iSchool
# ..                                                 ...
# 907                                  Actuarial science
# 909                                           Business
# 919                              Fine and Applied Arts
# 920                                               Gies
# 961                                                 CS
#
#     What do you think is the hardest major at UIUC?  \
# 11                                              NaN
# 20                                     Engineering
# 29                                     Music Theory
# 53                                          Biology
# 70                                Engineering PHDs
# ..                                              ...
# 907                                computer science
# 909                                     Engineering
# 919                                Computer Science
# 920                               Computer Science
# 961                                              CS
#
#     What genre of music do you listen to?  Who is your favorite music artist?  \
# 11                                    Yes                        Saint Asonia
# 20                                    R&B                                Joji
# 29                               Operetta                             Hot Dad
# 53                                   folk                           Beethoven
# 70                                  Happy                            NewJeans
# ..                                    ...                                 ...
# 907                               r and b                        Taylor swift
# 909                                   Rap                               Drake
# 919                           Many genres  King Gizzard and the Lizard Wizard
# 920                                   rap                              Giveon
# 961                                  Jazz                                  Ye
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 11                                  TikTok                        I-N-I
# 20                                  TikTok                        INOIS
# 29                                 Youtube              Ill? Get Better
# 53                                  wechat                     ai el el
# 70                               Instagram                         SICK
# ..                                     ...                          ...
# 907                                 TikTok                          Ill
# 909                               Snapchat                          INI
# 919                              Pinterest                        I-N-I
# 920                                tik tok                        I-N-I
# 961                                     QQ                         illi
#
#     What is your favorite game to play (either video game or IRL)?  \
# 11                                               Palia
# 20                                           Guess Who
# 29                                  Secrets of Grindea
# 53                                    football manager
# 70                                            Plate Up
# ..                                                 ...
# 907                                                NaN
# 909                                             Soccer
# 919                       Animal Crossing New Horizons
# 920                                           monopoly
# 961                                     Clash of clans
#
#     What is your dream vacation location?
# 11                                    NaN
# 20                                    NaN
# 29                             Seychelles
# 53                                  beach
# 70                                  Japan
# ..                                    ...
# 907                                France
# 909                         Isla  Mujeres
# 919                                 Japan
# 920                             bora bora
# 961                               Iceland
#
# [93 rows x 178 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df2_treatment' in vars() ), "You do not have a DataFrame called `df2_treatment`."
assert( 'df2_control' in vars() ), "You do not have a DataFrame called `df2_control`."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df2_control.index) ]) == 0), "The `df2_treatment` and `df2_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df1.index) ]) == 0), "The `df2_treatment` and `df1` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_control.index) & df.index.isin(df1.index) ]) == 0), "The `df2_control` and `df1` groups have some overlap!  There must be no overlap."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.5:
#
# Finally, read the guide: **Combining DataFrames by Concatenation** (https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/) to learn how to combine `df1_treatment` and `df2_treatment` together into one group called `treatment`.
#
# FYI, you will not need to reset the index here!

# %%
treatment = pd.concat([df1_treatment, df2_treatment])
treatment
# Out:
#         Name Section Does your NetID ending with odd number or even number?  \
# 631    Ginny     Y24                      NetID ends with an odd number
# 622     Alan     Y35                     NetID ends with an even number
# 591  Utkarsh     Y41                      NetID ends with an odd number
# 706    Ziyao     Y35                      NetID ends with an odd number
# 315      Tia     Y09                      NetID ends with an odd number
# ..       ...     ...                                                ...
# 406    James     Y22                      NetID ends with an odd number
# 55      Meng     Y08                      NetID ends with an odd number
# 677     Alex     Y24                     NetID ends with an even number
# 542     Reva     Y04                      NetID ends with an odd number
# 431  Matthew     Y22                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 631                                              Heads
# 622                                              Heads
# 591                                              Tails
# 706                                              Heads
# 315                                              Tails
# ..                                                 ...
# 406                                              Heads
# 55                                               Tails
# 677                                              Heads
# 542                                              Tails
# 431                                              Tails
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 631                               Tacos                    1.0
# 622                               Tacos                    1.0
# 591                              Donuts                    1.0
# 706                               Tacos                    0.0
# 315                               Tacos                    1.0
# ..                                  ...                    ...
# 406                              Donuts                    0.0
# 55                                Tacos                    0.0
# 677                               Tacos                    1.0
# 542                               Tacos                    0.0
# 431                              Donuts                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 631            Freshman in College                       Morning Person
# 622            Freshman in College                         Night Person
# 591            Freshman in College                         Night Person
# 706            Freshman in College                         Night Person
# 315            Freshman in College                       Morning Person
# ..                             ...                                  ...
# 406            Freshman in College                         Night Person
# 55             Freshman in College                       Morning Person
# 677            Freshman in College                         Night Person
# 542                 Not a Freshman                         Night Person
# 431            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 631                            Morning Person
# 622                          Afternoon Person
# 591                            Morning Person
# 706                          Afternoon Person
# 315                          Afternoon Person
# ..                                        ...
# 406                          Afternoon Person
# 55                             Morning Person
# 677                          Afternoon Person
# 542                          Afternoon Person
# 431                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 631                                     Out-of-state  ...
# 622                                         Illinois  ...
# 591                                     Out-of-state  ...
# 706                                     Out-of-state  ...
# 315                                     Out-of-state  ...
# ..                                               ...  ...
# 406                                         Illinois  ...
# 55                                          Illinois  ...
# 677                                         Illinois  ...
# 542                                         Illinois  ...
# 431                                         Illinois  ...
#
#     From 1 to 10, how happy are you right now?  \
# 631                                        7.0
# 622                                        8.0
# 591                                        7.0
# 706                                        6.0
# 315                                        7.0
# ..                                         ...
# 406                                        7.0
# 55                                         1.0
# 677                                        5.0
# 542                                        5.0
# 431                                        8.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 631                                               mild
# 622                                           moderate
# 591                                            extreme
# 706                                               mild
# 315                                           moderate
# ..                                                 ...
# 406                                               Mild
# 55                                                none
# 677                                             Strong
# 542                                           moderate
# 431                                                NaN
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 631                                              Math.
# 622                                               Gies
# 591                                                LAS
# 706                             electrical engineering
# 315                                                LAS
# ..                                                 ...
# 406                                           Business
# 55                                    computer science
# 677                                               Gies
# 542                                                LAS
# 431                                                LAS
#
#     What do you think is the hardest major at UIUC?  \
# 631                               computer science.
# 622                                Bio Engineering
# 591                          Astronomy+Data Science
# 706                                              CS
# 315                                         physics
# ..                                              ...
# 406                            Computer Engineering
# 55                                              ECE
# 677                                         Physics
# 542                          Biomedical engineering
# 431                           Aerospace Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 631                                   Pop                       Taylor Swift
# 622                           Pop/Rap/EDM                       Frank Ocean
# 591                          Taylor Swift                       Taylor Swift
# 706                           Vapour wave                           Jay Chou
# 315                                  kpop                              ateez
# ..                                    ...                                ...
# 406                               Country                     Zac Brown Band
# 55                                    R&B                       taylor swift
# 677                                  Rock                          Radiohead
# 542                                   pop                           Doja cat
# 431                               Country                      Kenny Chesney
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 631                                 wechat                     It's ok.
# 622                             Instagram                         I-N-I
# 591                                Youtube                       I-N-I!
# 706                                 wechat                         none
# 315                              instagram                        i-n-i
# ..                                     ...                          ...
# 406                              Instagram                        I-N-I
# 55                                     ins                    dont know
# 677                                Discord                        I-N-I
# 542                                 Tiktok                        I-N-I
# 431                               Snapchat                        I-N-I
#
#     What is your favorite game to play (either video game or IRL)?  \
# 631                               Talking Tom gold run
# 622                                            Hockey
# 591                                              Chess
# 706                                                IRL
# 315                                             spades
# ..                                                 ...
# 406                                           Football
# 55                                                none
# 677                                    Baldur's Gate 3
# 542                                      Monopoly deal
# 431                                         Basketball
#
#     What is your dream vacation location?
# 631                            California
# 622                               Greece
# 591                              Maldives
# 706                               Iceland
# 315                                 india
# ..                                    ...
# 406                                Alaska
# 55                                iceland
# 677                        St. Petersburg
# 542                               Greece
# 431                                Hawaii
#
# [470 rows x 178 columns]

# %% [markdown]
# ## Part 3.6:
#
# Using the same technique, combine `df1_control` and `df2_control` together into one group called `control`:

# %%
control = pd.concat([df1_control, df2_control])
control
# Out:
#             Name Section  \
# 0    Prof. Karle  L1, L2
# 7     Joseph Kim     Y16
# 15       Michael     Y03
# 17        Chuyan     Y24
# 19        Lauren     Y03
# ..           ...     ...
# 907      Tarina     Y20
# 909          Ben     Y29
# 919         Kate     Y13
# 920      Yamuna      Y34
# 961        Peter     Y09
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 7                       NetID ends with an even number
# 15                      NetID ends with an even number
# 17                      NetID ends with an even number
# 19                      NetID ends with an even number
# ..                                                 ...
# 907                      NetID ends with an odd number
# 909                      NetID ends with an odd number
# 919                     NetID ends with an even number
# 920                      NetID ends with an odd number
# 961                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 7                                                Heads
# 15                                               Heads
# 17                                               Heads
# 19                                               Heads
# ..                                                 ...
# 907                                              Heads
# 909                                              Tails
# 919                                              Tails
# 920                                              Tails
# 961                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 7                                Donuts                    1.0
# 15                                Tacos                    0.0
# 17                               Donuts                    0.0
# 19                                Tacos                    0.0
# ..                                  ...                    ...
# 907                               Tacos                    1.0
# 909                               Tacos                    0.0
# 919                               Tacos                    1.0
# 920                               Tacos                    1.0
# 961                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 7                   Not a Freshman                         Night Person
# 15                  Not a Freshman                         Night Person
# 17             Freshman in College                         Night Person
# 19                  Not a Freshman                         Night Person
# ..                             ...                                  ...
# 907            Freshman in College                         Night Person
# 909            Freshman in College                         Night Person
# 919                 Not a Freshman                       Morning Person
# 920            Freshman in College                         Night Person
# 961                 Not a Freshman                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 7                            Afternoon Person
# 15                           Afternoon Person
# 17                           Afternoon Person
# 19                             Morning Person
# ..                                        ...
# 907                          Afternoon Person
# 909                          Afternoon Person
# 919                            Morning Person
# 920                          Afternoon Person
# 961                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 7                                           Illinois  ...
# 15                                          Illinois  ...
# 17                                      Out-of-state  ...
# 19                                          Illinois  ...
# ..                                               ...  ...
# 907                                         Illinois  ...
# 909                                         Illinois  ...
# 919                                         Illinois  ...
# 920                                         Illinois  ...
# 961                                     Out-of-state  ...
#
#     From 1 to 10, how happy are you right now?  \
# 0                                          9.0
# 7                                          4.0
# 15                                        10.0
# 17                                         7.0
# 19                                         8.0
# ..                                         ...
# 907                                        8.0
# 909                                        8.0
# 919                                        9.0
# 920                                       10.0
# 961                                        5.0
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 7                                                 Mild
# 15                                             Extreme
# 17                                             extreme
# 19                                             Strong
# ..                                                 ...
# 907                                             strong
# 909                                               Mild
# 919                                           Moderate
# 920                                             strong
# 961                                             strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 7                                                  LAS
# 15                                                 LAS
# 17                                            business
# 19                                                 LAS
# ..                                                 ...
# 907                                  Actuarial science
# 909                                           Business
# 919                              Fine and Applied Arts
# 920                                               Gies
# 961                                                 CS
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 7                                  Computer Science
# 15                           Electrical Engineering
# 17                                               CS
# 19                                     Engineering
# ..                                              ...
# 907                                computer science
# 909                                     Engineering
# 919                                Computer Science
# 920                               Computer Science
# 961                                              CS
#
#     What genre of music do you listen to?  Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                        Taylor Swift
# 7                              soundtrack              Ski Mask the Slump God
# 15                             Indie rock                            Pavement
# 17                                    R&B                            Jay Chou
# 19                                    All                                 N/a
# ..                                    ...                                 ...
# 907                               r and b                        Taylor swift
# 909                                   Rap                               Drake
# 919                           Many genres  King Gizzard and the Lizard Wizard
# 920                                   rap                              Giveon
# 961                                  Jazz                                  Ye
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 7                                Instagram                    I-N-O-I-S
# 15                               Instagram                        I-N-I
# 17                                  Wechat                    Illinois?
# 19                                 Tik Tok                        I-N-I
# ..                                     ...                          ...
# 907                                 TikTok                          Ill
# 909                               Snapchat                          INI
# 919                              Pinterest                        I-N-I
# 920                                tik tok                        I-N-I
# 961                                     QQ                         illi
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 7    Super Smash Bros. Ultimate (Dear Karle and Wad...
# 15                                            Baseball
# 17                                                none
# 19                                                 N/a
# ..                                                 ...
# 907                                                NaN
# 909                                             Soccer
# 919                       Animal Crossing New Horizons
# 920                                           monopoly
# 961                                     Clash of clans
#
#     What is your dream vacation location?
# 0                            The Maldives
# 7                                 Nowhere
# 15                                 France
# 17         travel with friends and family
# 19                                  Japan
# ..                                    ...
# 907                                France
# 909                         Isla  Mujeres
# 919                                 Japan
# 920                             bora bora
# 961                               Iceland
#
# [470 rows x 178 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Blocking

# %% [markdown]
# **Q: In your own words, explain what blocking is and why it is useful to someone who has never taken a statistics course before! You can use what you did above as an example in your explanation if you'd like. Make sure to include what blocking is and why it is useful. Write at least three complete sentences to answer this question.**

# %% [markdown]
# Blocking is the process in which we "block" the subjects in a given experiment which is where we put people who have things in common with each other first before we randomly assign the treatments and control groups within each set of "blocks". The reason why this is useful is that in bigger samples, random differences within the participants that may affect our data are typically evened out, but with smaller sample sizes, a "small" difference within the subjects could lead to misleading results. By first blocking, participants that have this common "difference" are separated from the other block and we collect data from each block which allows us to get quality data without any circumstances.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
